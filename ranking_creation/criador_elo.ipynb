# %%
import os
import pandas as pd

# Define the absolute path to the data directory
data_dir = 'C:\\Users\\Cristina Jorge\\OneDrive\\Documentos\\GitHub\\Back-End-Elo\\data'

# Read the datasets
Brasileiro = pd.read_csv(os.path.join(data_dir, 'dataBRA.csv'))
Brasileiro23 = pd.read_csv(os.path.join(data_dir, 'serieA_2023_matches.csv'))
SérieB = pd.read_csv(os.path.join(data_dir, 'dataBRB.csv'))
SérieB23 = pd.read_csv(os.path.join(data_dir, 'serieB_2023_matches.csv'))
SérieC = pd.read_csv(os.path.join(data_dir, 'dataBRC.csv'))
SérieC23 = pd.read_csv(os.path.join(data_dir, 'serieC_2023_matches.csv'))
Copa = pd.read_csv(os.path.join(data_dir, 'dataCBR.csv'))
Copa23 = pd.read_csv(os.path.join(data_dir, 'dataCBR2023.csv'))

# Merge dataframes and sort by date
frames = [Brasileiro, Brasileiro23, SérieB, SérieB23, SérieC, SérieC23, Copa, Copa23]
df = pd.concat(frames)
df = df.drop_duplicates()
df['Data'] = pd.to_datetime(df['Data'], infer_datetime_format=True, errors='coerce')
df = df.sort_values(by='Data')
df.to_csv(os.path.join(data_dir, 'dataELO.csv'), index=False)
# Out:
# C:\Users\Cristina Jorge\AppData\Local\Temp\ipykernel_12836\2345843694.py:21: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Data'] = pd.to_datetime(df['Data'], infer_datetime_format=True, errors='coerce')

# %%
df.tail(30)
# Out:
#         Comp    Temp       Data            Casa   GC   GF  \
# 366  Série B  2023.0 2023-11-18       Juventude  0.0  0.0
# 365  Série B  2023.0 2023-11-18         Vitória  1.0  0.0
# 362  Série B  2023.0 2023-11-18    Vila Nova-GO  3.0  1.0
# 368  Série B  2023.0 2023-11-19             CRB  2.0  0.0
# 367  Série B  2023.0 2023-11-19         Guarani  2.0  3.0
# 369  Série B  2023.0 2023-11-20  Sampaio Corrêa  4.0  0.0
# 336  Série A  2023.0 2023-11-22      Fluminense  1.0  0.0
# 335  Série A  2023.0 2023-11-22        Cruzeiro  2.0  2.0
# 338  Série A  2023.0 2023-11-23       Fortaleza  2.0  2.0
# 337  Série A  2023.0 2023-11-23        Flamengo  1.0  0.0
# 339  Série A  2023.0 2023-11-24     Corinthians  1.0  5.0
# 340  Série A  2023.0 2023-11-25      Fluminense  2.0  1.0
# 341  Série A  2023.0 2023-11-25    Athletico-PR  0.0  0.0
# 376  Série B  2023.0 2023-11-25     Atlético-GO  3.0  0.0
# 370  Série B  2023.0 2023-11-25           Ceará  1.0  3.0
# 371  Série B  2023.0 2023-11-25           Sport  4.0  1.0
# 372  Série B  2023.0 2023-11-25     Chapecoense  3.0  1.0
# 373  Série B  2023.0 2023-11-25   Novorizontino  2.0  0.0
# 374  Série B  2023.0 2023-11-25        Tombense  0.0  1.0
# 379  Série B  2023.0 2023-11-25             ABC  3.0  2.0
# 378  Série B  2023.0 2023-11-25     Botafogo-SP  0.0  1.0
# 377  Série B  2023.0 2023-11-25     Ponte Preta  3.0  0.0
# 375  Série B  2023.0 2023-11-25            Avaí  0.0  0.0
# 342  Série A  2023.0 2023-11-26       Fortaleza  2.0  2.0
# 343  Série A  2023.0 2023-11-26   Internacional  1.0  0.0
# 344  Série A  2023.0 2023-11-26      América-MG  0.0  3.0
# 345  Série A  2023.0 2023-11-26       São Paulo  0.0  0.0
# 346  Série A  2023.0 2023-11-26        Botafogo  1.0  1.0
# 347  Série A  2023.0 2023-11-26     Atlético-MG  3.0  0.0
# 348  Série A  2023.0 2023-11-27           Goiás  0.0  1.0
#
#                     Fora Res   PC   PF      J
# 366          Ponte Preta   E  1.0  1.0  367.0
# 365                Sport  VC  3.0  0.0  366.0
# 362                Ceará  VC  3.0  0.0  363.0
# 368             Tombense  VC  3.0  0.0  369.0
# 367                  ABC  VV  0.0  3.0  368.0
# 369                 Avaí  VC  3.0  0.0  370.0
# 336            São Paulo  VC  3.0  0.0  338.0
# 335                Vasco   E  1.0  1.0  337.0
# 338             Botafogo   E  1.0  1.0  340.0
# 337  Red Bull Bragantino  VC  3.0  0.0  339.0
# 339                Bahia  VV  0.0  3.0  341.0
# 340             Coritiba  VC  3.0  0.0  342.0
# 341                Vasco   E  1.0  1.0  343.0
# 376              Guarani  VC  3.0  0.0  377.0
# 370            Juventude  VV  0.0  3.0  371.0
# 371       Sampaio Corrêa  VC  3.0  0.0  372.0
# 372              Vitória  VC  3.0  0.0  373.0
# 373             Criciúma  VC  3.0  0.0  374.0
# 374             Mirassol  VV  0.0  3.0  375.0
# 379         Vila Nova-GO  VC  3.0  0.0  380.0
# 378             Londrina  VV  0.0  3.0  379.0
# 377                  CRB  VC  3.0  0.0  378.0
# 375               Ituano   E  1.0  1.0  376.0
# 342            Palmeiras   E  1.0  1.0  344.0
# 343  Red Bull Bragantino  VC  3.0  0.0  345.0
# 344             Flamengo  VV  0.0  3.0  346.0
# 345               Cuiabá   E  1.0  1.0  347.0
# 346               Santos   E  1.0  1.0  348.0
# 347               Grêmio  VC  3.0  0.0  349.0
# 348             Cruzeiro  VV  0.0  3.0  350.0

# %%
df

# %%
#I use this to make sure that was no duplicates in the DF
import Levenshtein

def are_similar(s1, s2, threshold=0.85):
    distance = Levenshtein.distance(s1.lower(), s2.lower())
    similarity = 1 - distance / max(len(s1), len(s2))
    return similarity >= threshold

# Your DataFrame containing the 'Casa' column
# Assuming you have already converted the "Data" column to pandas datetime format
df['Data'] = pd.to_datetime(df['Data'])

# Generate a list of unique values from the 'Casa' column and sort them
unique_values = df['Fora'].unique()
unique_values_sorted = sorted(unique_values)

# Find semiduplicates using Levenshtein distance with a threshold of 0.9 (90% similarity)
semiduplicates = []

for i in range(len(unique_values_sorted)):
    for j in range(i + 1, len(unique_values_sorted)):
        if are_similar(unique_values_sorted[i], unique_values_sorted[j]):
            semiduplicates.append((unique_values_sorted[i], unique_values_sorted[j]))

print("Semiduplicates:")
for pair in semiduplicates:
    print(f"{pair[0]} and {pair[1]} are similar.")
