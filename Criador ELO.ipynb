# %%
#Unites the different datasets

import pandas as pd

Brasileiro = pd.read_csv('dataBRA.csv')
Brasileiro23 = pd.read_csv('dataBRA23.csv')
SérieB = pd.read_csv('dataBRB.csv')
SérieB23 = pd.read_csv('dataBRB23.csv')
Copa = pd.read_csv('dataCBR.csv')
Copa23 = pd.read_csv('dataCBR2023.csv')

# Merge dataframes and sort by date
frames = [Brasileiro, Brasileiro23, SérieB, SérieB23, Copa, Copa23]
df = pd.concat(frames)
df = df.drop_duplicates()
df = df.sort_values(by='Data')
df.to_csv('dataELO.csv', index=False)
df
# Out:
#         Comp  Temp        Data         Casa  GC  GF         Fora Res  PC  PF  \
# 13       CBR  2003  2003-02-05        Bangu   2   1         Gama  VC   3   0
# 12       CBR  2003  2003-02-05      Pelotas   1   2      Guarani  VV   0   3
# 11       CBR  2003  2003-02-05  Botafogo-PB   1   4     Flamengo  VV   0   3
# 10       CBR  2003  2003-02-05       CFZ-DF   0   0    Fortaleza   E   1   1
# 9        CBR  2003  2003-02-05          CRB   0   1  Atlético-MG  VV   0   3
# ..       ...   ...         ...          ...  ..  ..          ...  ..  ..  ..
# 186  Série B  2023  2023-07-24      Vitória   1   0  Chapecoense  VC   3   0
# 157  Série A  2023  2023-07-24     Coritiba   2   0   Fluminense  VC   3   0
# 187  Série B  2023  2023-07-24     Londrina   1   2  Botafogo-SP  VV   0   3
# 116      CBR  2023  2023-07-25  Corinthians   2   1    São Paulo  VC   3   0
# 117      CBR  2023  2023-07-26       Grêmio   0   2     Flamengo  VV   0   3
#
#        J
# 13    12
# 12    10
# 11     7
# 10    11
# 9      3
# ..   ...
# 186  187
# 157  158
# 187  188
# 116  117
# 117  118
#
# [17662 rows x 11 columns]

# %%
df.tail(30)
# Out:
#         Comp  Temp        Data                 Casa  GC  GF            Fora  \
# 169  Série B  2023  2023-07-18          Ponte Preta   0   0       Juventude
# 171  Série B  2023  2023-07-18             Tombense   2   1             CRB
# 175  Série B  2023  2023-07-19                 Avaí   2   0  Sampaio Corrêa
# 177  Série B  2023  2023-07-19        Novorizontino   3   0        Londrina
# 176  Série B  2023  2023-07-19          Atlético-GO   2   2        Mirassol
# 174  Série B  2023  2023-07-19                Sport   1   2         Vitória
# 173  Série B  2023  2023-07-19                  ABC   0   1         Guarani
# 172  Série B  2023  2023-07-19                Ceará   1   0    Vila Nova-GO
# 178  Série B  2023  2023-07-21                  CRB   1   0     Ponte Preta
# 182  Série B  2023  2023-07-22             Mirassol   2   0        Tombense
# 181  Série B  2023  2023-07-22               Ituano   0   1            Avaí
# 180  Série B  2023  2023-07-22             Criciúma   0   1   Novorizontino
# 179  Série B  2023  2023-07-22         Vila Nova-GO   1   1             ABC
# 152  Série A  2023  2023-07-22            Palmeiras   3   1       Fortaleza
# 148  Série A  2023  2023-07-22               Cuiabá   2   1       São Paulo
# 149  Série A  2023  2023-07-22                Bahia   0   0     Corinthians
# 150  Série A  2023  2023-07-22               Grêmio   1   0     Atlético-MG
# 151  Série A  2023  2023-07-22             Flamengo   1   1      América-MG
# 156  Série A  2023  2023-07-23                Vasco   0   2    Athletico-PR
# 155  Série A  2023  2023-07-23               Santos   2   2        Botafogo
# 185  Série B  2023  2023-07-23            Juventude   1   0           Ceará
# 153  Série A  2023  2023-07-23  Red Bull Bragantino   0   0   Internacional
# 184  Série B  2023  2023-07-23              Guarani   1   0     Atlético-GO
# 154  Série A  2023  2023-07-23             Cruzeiro   0   1           Goiás
# 183  Série B  2023  2023-07-23       Sampaio Corrêa   1   2           Sport
# 186  Série B  2023  2023-07-24              Vitória   1   0     Chapecoense
# 157  Série A  2023  2023-07-24             Coritiba   2   0      Fluminense
# 187  Série B  2023  2023-07-24             Londrina   1   2     Botafogo-SP
# 116      CBR  2023  2023-07-25          Corinthians   2   1       São Paulo
# 117      CBR  2023  2023-07-26               Grêmio   0   2        Flamengo
#
#     Res  PC  PF    J
# 169   E   1   1  170
# 171  VC   3   0  172
# 175  VC   3   0  176
# 177  VC   3   0  178
# 176   E   1   1  177
# 174  VV   0   3  175
# 173  VV   0   3  174
# 172  VC   3   0  173
# 178  VC   3   0  179
# 182  VC   3   0  183
# 181  VV   0   3  182
# 180  VV   0   3  181
# 179   E   1   1  180
# 152  VC   3   0  153
# 148  VC   3   0  149
# 149   E   1   1  150
# 150  VC   3   0  151
# 151   E   1   1  152
# 156  VV   0   3  157
# 155   E   1   1  156
# 185  VC   3   0  186
# 153   E   1   1  154
# 184  VC   3   0  185
# 154  VV   0   3  155
# 183  VV   0   3  184
# 186  VC   3   0  187
# 157  VC   3   0  158
# 187  VV   0   3  188
# 116  VC   3   0  117
# 117  VV   0   3  118

# %%
import Levenshtein

def are_similar(s1, s2, threshold=0.85):
    distance = Levenshtein.distance(s1.lower(), s2.lower())
    similarity = 1 - distance / max(len(s1), len(s2))
    return similarity >= threshold

# Your DataFrame containing the 'Casa' column
# Assuming you have already converted the "Data" column to pandas datetime format
df['Data'] = pd.to_datetime(df['Data'])

# Generate a list of unique values from the 'Casa' column and sort them
unique_values = df['Fora'].unique()
unique_values_sorted = sorted(unique_values)

# Find semiduplicates using Levenshtein distance with a threshold of 0.9 (90% similarity)
semiduplicates = []

for i in range(len(unique_values_sorted)):
    for j in range(i + 1, len(unique_values_sorted)):
        if are_similar(unique_values_sorted[i], unique_values_sorted[j]):
            semiduplicates.append((unique_values_sorted[i], unique_values_sorted[j]))

print("Semiduplicates:")
for pair in semiduplicates:
    print(f"{pair[0]} and {pair[1]} are similar.")
# Out:
# Semiduplicates:
# Operário-MS and Operário-MT are similar.
# São Raimundo-AM and São Raimundo-PA are similar.
# São Raimundo-AM and São Raimundo-RR are similar.
# São Raimundo-PA and São Raimundo-RR are similar.

# %%
filt = ((df['Casa'] == 'Maringá  .'))
df[filt]
# Out:
#    Comp  Temp       Data        Casa  GC  GF            Fora Res  PC  PF   J
# 38  CBR  2023 2023-03-02  Maringá  .   2   1  Sampaio Corrêa  VC   3   0  39
# 47  CBR  2023 2023-03-14  Maringá  .   2   0   Marcílio Dias  VC   3   0  48
# 75  CBR  2023 2023-04-13  Maringá  .   2   0        Flamengo  VC   3   0  76

# %%
Copa23.replace({' Maringá  .': 'Maringá',
    'Vila Nova': 'Vila Nova-GO',
            }, inplace=True)
Copa23.to_csv('dataCBR2023.csv', index=False)
