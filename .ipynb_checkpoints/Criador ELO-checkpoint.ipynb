# %%
#Unites the different datasets

import pandas as pd

Brasileiro = pd.read_csv('dataBRA.csv')
Brasileiro23 = pd.read_csv('dataBRA23.csv')
SérieB = pd.read_csv('dataBRB.csv')
SérieB23 = pd.read_csv('dataBRB23.csv')
Copa = pd.read_csv('dataCBR.csv')
Copa23 = pd.read_csv('dataCBR2023.csv')

# Merge dataframes and sort by date
frames = [Brasileiro, Brasileiro23, SérieB, SérieB23, Copa, Copa23]
df = pd.concat(frames)
df = df.drop_duplicates()
df = df.sort_values(by='Data')
df.to_csv('dataELO.csv', index=False)
df
# Out:
#         Comp  Temp        Data          Casa  GC  GF           Fora Res  PC  \
# 13       CBR  2003  2003-02-05         Bangu   2   1           Gama  VC   3
# 12       CBR  2003  2003-02-05       Pelotas   1   2        Guarani  VV   0
# 11       CBR  2003  2003-02-05   Botafogo-PB   1   4       Flamengo  VV   0
# 10       CBR  2003  2003-02-05        CFZ-DF   0   0      Fortaleza   E   1
# 9        CBR  2003  2003-02-05           CRB   0   1    Atlético-MG  VV   0
# ..       ...   ...         ...           ...  ..  ..            ...  ..  ..
# 203  Série B  2023  2023-08-02     Juventude   1   0  Novorizontino  VC   3
# 204  Série B  2023  2023-08-02  Vila Nova-GO   0   1          Sport  VV   0
# 205  Série B  2023  2023-08-02       Guarani   0   0          Ceará   E   1
# 207  Série B  2023  2023-08-02      Londrina   1   1    Chapecoense   E   1
# 206  Série B  2023  2023-08-02      Criciúma   2   1    Ponte Preta  VC   3
#
#      PF    J
# 13    0   12
# 12    3   10
# 11    3    7
# 10    1   11
# 9     3    3
# ..   ..  ...
# 203   0  204
# 204   3  205
# 205   1  206
# 207   1  208
# 206   0  207
#
# [17692 rows x 11 columns]

# %%
df.tail(30)
# Out:
#         Comp  Temp        Data            Casa  GC  GF                 Fora  \
# 189  Série B  2023  2023-07-28           Ceará   1   1               Ituano
# 188  Série B  2023  2023-07-28           Sport   2   0                  CRB
# 158  Série A  2023  2023-07-29       Fortaleza   0   3  Red Bull Bragantino
# 194  Série B  2023  2023-07-29     Botafogo-SP   0   2            Juventude
# 193  Série B  2023  2023-07-29            Avaí   1   2              Guarani
# 191  Série B  2023  2023-07-29     Chapecoense   0   1             Mirassol
# 190  Série B  2023  2023-07-29             ABC   0   0             Londrina
# 192  Série B  2023  2023-07-29     Atlético-GO   2   2       Sampaio Corrêa
# 163  Série A  2023  2023-07-29    Athletico-PR   3   3             Cruzeiro
# 162  Série A  2023  2023-07-29   Internacional   1   2               Cuiabá
# 161  Série A  2023  2023-07-29     Atlético-MG   1   2             Flamengo
# 160  Série A  2023  2023-07-29     Corinthians   3   1                Vasco
# 159  Série A  2023  2023-07-29      Fluminense   1   0               Santos
# 166  Série A  2023  2023-07-30        Botafogo   4   1             Coritiba
# 197  Série B  2023  2023-07-30        Tombense   2   2             Criciúma
# 165  Série A  2023  2023-07-30      América-MG   1   4            Palmeiras
# 195  Série B  2023  2023-07-30     Ponte Preta   2   2              Vitória
# 196  Série B  2023  2023-07-30   Novorizontino   3   1         Vila Nova-GO
# 164  Série A  2023  2023-07-30       São Paulo   0   0                Bahia
# 167  Série A  2023  2023-07-30           Goiás   1   1               Grêmio
# 198  Série B  2023  2023-08-01        Mirassol   2   2                 Avaí
# 199  Série B  2023  2023-08-01  Sampaio Corrêa   0   0          Botafogo-SP
# 200  Série B  2023  2023-08-01             CRB   2   1          Atlético-GO
# 201  Série B  2023  2023-08-02         Vitória   2   0                  ABC
# 202  Série B  2023  2023-08-02          Ituano   1   0             Tombense
# 203  Série B  2023  2023-08-02       Juventude   1   0        Novorizontino
# 204  Série B  2023  2023-08-02    Vila Nova-GO   0   1                Sport
# 205  Série B  2023  2023-08-02         Guarani   0   0                Ceará
# 207  Série B  2023  2023-08-02        Londrina   1   1          Chapecoense
# 206  Série B  2023  2023-08-02        Criciúma   2   1          Ponte Preta
#
#     Res  PC  PF    J
# 189   E   1   1  190
# 188  VC   3   0  189
# 158  VV   0   3  159
# 194  VV   0   3  195
# 193  VV   0   3  194
# 191  VV   0   3  192
# 190   E   1   1  191
# 192   E   1   1  193
# 163   E   1   1  164
# 162  VV   0   3  163
# 161  VV   0   3  162
# 160  VC   3   0  161
# 159  VC   3   0  160
# 166  VC   3   0  167
# 197   E   1   1  198
# 165  VV   0   3  166
# 195   E   1   1  196
# 196  VC   3   0  197
# 164   E   1   1  165
# 167   E   1   1  168
# 198   E   1   1  199
# 199   E   1   1  200
# 200  VC   3   0  201
# 201  VC   3   0  202
# 202  VC   3   0  203
# 203  VC   3   0  204
# 204  VV   0   3  205
# 205   E   1   1  206
# 207   E   1   1  208
# 206  VC   3   0  207

# %%
import Levenshtein

def are_similar(s1, s2, threshold=0.85):
    distance = Levenshtein.distance(s1.lower(), s2.lower())
    similarity = 1 - distance / max(len(s1), len(s2))
    return similarity >= threshold

# Your DataFrame containing the 'Casa' column
# Assuming you have already converted the "Data" column to pandas datetime format
df['Data'] = pd.to_datetime(df['Data'])

# Generate a list of unique values from the 'Casa' column and sort them
unique_values = df['Fora'].unique()
unique_values_sorted = sorted(unique_values)

# Find semiduplicates using Levenshtein distance with a threshold of 0.9 (90% similarity)
semiduplicates = []

for i in range(len(unique_values_sorted)):
    for j in range(i + 1, len(unique_values_sorted)):
        if are_similar(unique_values_sorted[i], unique_values_sorted[j]):
            semiduplicates.append((unique_values_sorted[i], unique_values_sorted[j]))

print("Semiduplicates:")
for pair in semiduplicates:
    print(f"{pair[0]} and {pair[1]} are similar.")
# Out:
# Semiduplicates:
# Operário-MS and Operário-MT are similar.
# São Raimundo-AM and São Raimundo-PA are similar.
# São Raimundo-AM and São Raimundo-RR are similar.
# São Raimundo-PA and São Raimundo-RR are similar.

# %%
filt = ((df['Casa'] == 'Maringá  .'))
df[filt]
# Out:
#    Comp  Temp       Data        Casa  GC  GF            Fora Res  PC  PF   J
# 38  CBR  2023 2023-03-02  Maringá  .   2   1  Sampaio Corrêa  VC   3   0  39
# 47  CBR  2023 2023-03-14  Maringá  .   2   0   Marcílio Dias  VC   3   0  48
# 75  CBR  2023 2023-04-13  Maringá  .   2   0        Flamengo  VC   3   0  76

# %%
Copa23.replace({' Maringá  .': 'Maringá',
    'Vila Nova': 'Vila Nova-GO',
            }, inplace=True)
Copa23.to_csv('dataCBR2023.csv', index=False)
